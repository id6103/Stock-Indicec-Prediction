# %%
import pandas as pd

news_final = pd.read_json("newsFinal13.json")
# news_final

# %%
# news_final["submissions"][0]

# %%
#sort with time desc
news_final = news_final.iloc[::-1]
news_final.index = range(len(news_final))
len(news_final)
# Out:
# 2301

# %%
import nltk
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/nbuser/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/nbuser/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/nbuser/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/nbuser/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/nbuser/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/nbuser/nltk_data...
# ...

# %%
# print (news_final['submissions'][0])
# print (news_final['submissions'][0][0])
# print (news_final['submissions'][0][0]['title'])
import pandas as pd
# print (news_final['submissions'][0][1]['title'])
sentiment_data13 = pd.DataFrame(columns=(['date','score','num_comments','neg','neu','pos','compound']))
# sentiment_data13

# %%
import pandas as pd
import numpy as np
    
from nltk.sentiment.vader import SentimentIntensityAnalyzer
    
sid = SentimentIntensityAnalyzer()



for i in range(0,len(news_final)):
    for j in range(0,10):
    
      daily_news = news_final['submissions'][i][j]['title']
      ss = sid.polarity_scores(daily_news)
      date = news_final['startAt'][i]
      score = news_final['submissions'][i][j]['score']
      num_comments = news_final['submissions'][i][j]['num_comments']
      neg = float(ss['neg'])
      neu = ss['neu']
      pos = ss['pos']
      compound = ss['compound']
      sentiment_data13.loc[len(sentiment_data13)]=[str(date), score, num_comments,neg,neu,pos,compound]
      

# sentiment_data13

# %%
sentiment_data13.to_csv("sentiment_data13.csv", index = False)

# %%
import pandas as pd

news_final = pd.read_json("newsFinal13.json")

# %%
# TF - IDF
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

content = []

# for i in range(0,l):
for i in range(0,len(news_final)):
    for j in range(0,10):
      content.append(news_final['submissions'][i][j]['title'])
      
# print (content)
tvz = TfidfVectorizer(max_features = 200, max_df = 0.8,sublinear_tf=True, use_idf =True, stop_words = 'english')
X = tvz.fit_transform(content)
feature_names = tvz.get_feature_names()
dense = X.todense()
denselist = dense.tolist()

tfidf13 = pd.DataFrame(denselist, columns=feature_names)

# %%
tfidf13.to_csv("tfidf13.csv", index = False)

# %%
import pandas as pd

sentiment_data13 = pd.read_csv("sentiment_data13.csv")

# %%
#merge sentiment and tfidf
sentiment_tfidf13 = pd.concat([sentiment_data13, tfidf13], axis=1)
sentiment_tfidf13.to_csv("sentiment_tfidf13.csv", index = False)

# %%
import time

mean_sentiment_tfidf13 = sentiment_tfidf13.groupby(['date'], as_index=False).mean()
mean_sentiment_tfidf13 = mean_sentiment_tfidf13.assign()
mean_sentiment_tfidf13.to_csv("mean_sentimentAidf13.csv", index = False)

# %%
#convert epoch to date yyyy-mm-dd

for k in range(0, len(mean_sentiment_tfidf13)):
    mean_sentiment_tfidf13['date'][k]= time.strftime('%Y-%m-%d', time.localtime(int(mean_sentiment_tfidf13['date'][k])))


mean_sentiment_tfidf13.to_csv("mean_sentiment_tfidf13.csv", index = False)
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
mean_sentiment_tfidf13
# Out:
#             date    score  num_comments     neg     neu     pos  compound  \
# 0     2011-12-26    211.9          37.9  0.1585  0.7768  0.0648  -0.35517
# 1     2011-12-27    265.0          62.3  0.0854  0.8261  0.0886   0.08842
# 2     2011-12-28    215.3          26.5  0.1055  0.8434  0.0509  -0.19519
# 3     2011-12-29    233.8          77.4  0.1665  0.8114  0.0220  -0.33618
# 4     2011-12-30    175.5          75.1  0.1082  0.8354  0.0564  -0.14701
# 5     2011-12-31    244.1          21.3  0.1027  0.7968  0.1006   0.03649
# 6     2012-01-01    153.6          41.8  0.2138  0.7261  0.0602  -0.39026
# 7     2012-01-02    308.8          58.2  0.1746  0.7650  0.0604  -0.25180
# 8     2012-01-03    181.4          51.9  0.1673  0.7718  0.0609  -0.25666
# 9     2012-01-04    203.9          52.3  0.1393  0.8386  0.0221  -0.19342
# 10    2012-01-05    235.2          41.1  0.2288  0.7164  0.0548  -0.43864
# 11    2012-01-06    217.4          34.8  0.1343  0.8206  0.0450  -0.23281
# ...
