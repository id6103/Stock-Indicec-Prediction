# %%
#import and process Dow Jon Futures history 
import pandas as pd
from pprint import pprint

pf = pd.read_json("historyIndex.json")
#add one more label column in the each row (Last day)
futuresData = pd.DataFrame(columns=pf['dataset']['column_names'], data = pf['dataset']['data'])
futuresData = futuresData.iloc[::-1]
futuresData.index = range(len(futuresData))
y = futuresData.loc[1:2630, ['Last']]
y.index = range(len(y))
y.columns = ['Next Day Last']
futuresData = pd.merge(futuresData, y, left_index=True, right_index=True)
futuresData.drop(['Change'], axis = 1, inplace = True, errors = 'ignore')

# %%
#import and process the sentiment of the reddit sumissions title
newsData = pd.read_csv("mean_sentiment_tfidf13.csv")
# sentimentData.columns=['Date','neg','neu','pos','compound']
futuresData.columns=['date', 'Open', 'High', 'Low', 'Last', 'Settle', 'Volume',
       'Previous Day Open Interest', 'Next Day Last']

# %%
#merge imported data
dataset = newsData.merge(futuresData, on='date', how='left')
dataset = dataset.dropna(how='any')  #TODO
dataset.index = range(len(dataset))
dataset = dataset.drop(["Last"],axis=1) #TODO
dataset
# Out:
#             date    score  num_comments     neg     neu     pos  compound  \
# 0     2012-11-13    583.2         111.1  0.0976  0.8766  0.0258  -0.23890
# 1     2012-11-14    590.2         107.0  0.1501  0.8095  0.0404  -0.25605
# 2     2012-11-15    561.3         131.4  0.1332  0.7952  0.0716  -0.19940
# 3     2012-11-16    416.2         103.3  0.1469  0.8045  0.0487  -0.21828
# 4     2012-11-19    479.1          69.7  0.2267  0.7021  0.0712  -0.31749
# 5     2012-11-20    406.0          74.3  0.1351  0.7699  0.0950  -0.07062
# 6     2012-11-21    490.8          99.4  0.1228  0.7683  0.1089   0.04511
# 7     2012-11-23    519.6          76.9  0.1791  0.7749  0.0460  -0.20363
# 8     2012-11-26    455.4          73.7  0.0941  0.8235  0.0824   0.04249
# 9     2012-11-27    374.8          65.5  0.1517  0.8031  0.0452  -0.20032
# 10    2012-11-28    693.9         154.6  0.1733  0.7966  0.0300  -0.36568
# 11    2012-11-29    390.9         115.3  0.0527  0.7843  0.1628   0.25013
# 12    2012-11-30    598.9         114.4  0.0711  0.8186  0.1103   0.12341
# 13    2012-12-03    415.3         101.7  0.1128  0.7480  0.1392   0.05820
# 14    2012-12-04    598.6         146.6  0.1155  0.8192  0.0653  -0.13956
# 15    2012-12-05    416.3          74.1  0.2143  0.7620  0.0237  -0.44485
# 16    2012-12-06    646.7          82.4  0.1296  0.7994  0.0710  -0.10557
# 17    2012-12-07    272.8          81.4  0.2401  0.7143  0.0458  -0.42306
# 18    2012-12-10    597.9         129.4  0.1371  0.7909  0.0720  -0.21316
# 19    2012-12-11    426.0          70.7  0.0766  0.8599  0.0636  -0.04091
# 20    2012-12-12    474.9         165.1  0.2238  0.7611  0.0151  -0.31805
# 21    2012-12-13    615.3         161.7  0.1243  0.8331  0.0426  -0.21588
# 22    2012-12-14    929.5        1002.0  0.2549  0.6995  0.0456  -0.43120
# 23    2012-12-17    691.3         149.2  0.1530  0.7944  0.0525  -0.28309
# 24    2012-12-18    463.1         117.0  0.1535  0.8108  0.0357  -0.28895
# 25    2012-12-19    713.7         243.7  0.1176  0.8291  0.0533  -0.24895
# 26    2012-12-20    438.3         138.7  0.1931  0.7545  0.0524  -0.28657
# 27    2012-12-21    518.5         178.6  0.2119  0.7482  0.0399  -0.35047
# 28    2012-12-24    478.0         154.4  0.1995  0.7572  0.0434  -0.36153
# 29    2012-12-26    541.0         236.3  0.1010  0.8623  0.0367  -0.23175
# ...          ...      ...           ...     ...     ...     ...       ...
# 1324  2018-02-21  19818.1        2930.9  0.1729  0.7385  0.0887  -0.21500
# 1325  2018-02-22  18252.3        2306.2  0.1499  0.7700  0.0801  -0.14026
# 1326  2018-02-23  17442.9        3686.6  0.1818  0.7951  0.0231  -0.31358
# 1327  2018-02-26  16626.7        1364.1  0.1308  0.7762  0.0929  -0.08129
# 1328  2018-02-27  15163.8        2804.3  0.1926  0.7462  0.0612  -0.26685
# 1329  2018-02-28  19945.6        3723.7  0.1540  0.7546  0.0914  -0.12444
# 1330  2018-03-01  12586.2        1713.8  0.1890  0.7683  0.0427  -0.24156
# 1331  2018-03-02  22835.0        2651.9  0.1722  0.8027  0.0251  -0.34947
# 1332  2018-03-05  14908.1        1547.4  0.0734  0.8881  0.0385  -0.07532
# 1333  2018-03-06  15634.4        1325.8  0.1488  0.8149  0.0363  -0.24245
# 1334  2018-03-07  13875.1        1953.7  0.1149  0.8335  0.0515  -0.16611
# 1335  2018-03-08  14883.4        1436.6  0.1093  0.8569  0.0338  -0.12713
# 1336  2018-03-09  22382.5        2489.8  0.2321  0.7507  0.0172  -0.33882
# 1337  2018-03-12   9928.2        1053.1  0.1990  0.7527  0.0483  -0.28139
# 1338  2018-03-13  16511.6        1847.6  0.2184  0.7124  0.0692  -0.26679
# 1339  2018-03-14  86346.6        5518.5  0.2393  0.7164  0.0443  -0.36527
# 1340  2018-03-15  23021.7        3122.8  0.2735  0.6629  0.0638  -0.35954
# 1341  2018-03-16  15259.8        1858.2  0.0970  0.7901  0.1130  -0.03306
# 1342  2018-03-19  16815.1        1428.8  0.1282  0.7849  0.0869  -0.06474
# 1343  2018-03-20  21603.4        3594.8  0.1158  0.8187  0.0655  -0.15053
# 1344  2018-03-21  16770.3        2234.0  0.1486  0.8354  0.0160  -0.20886
# 1345  2018-03-22  19717.6        2390.3  0.3807  0.6193  0.0000  -0.58831
# 1346  2018-03-23  16556.5        1621.3  0.1328  0.8218  0.0453  -0.17221
# 1347  2018-03-26  18074.1        2042.1  0.1917  0.7680  0.0402  -0.28184
# 1348  2018-03-27  19916.2        1723.1  0.1918  0.7977  0.0105  -0.33007
# 1349  2018-03-28  19083.8        1814.7  0.2131  0.7016  0.0854  -0.27523
# 1350  2018-03-29  14420.9        3079.6  0.0668  0.8695  0.0637   0.04495
# 1351  2018-04-02   7769.3         910.2  0.1202  0.8130  0.0669  -0.10667
# 1352  2018-04-03   9565.3        1882.6  0.1457  0.7274  0.1269  -0.11664
# 1353  2018-04-04  13314.7        3406.4  0.0917  0.8444  0.0639  -0.06000
#
#            000        10       100      ...            year     years  \
# 0     0.000000  0.000000  0.000000      ...        0.000000  0.000000
# 1     0.000000  0.000000  0.000000      ...        0.000000  0.042984
# 2     0.000000  0.000000  0.000000      ...        0.000000  0.000000
# 3     0.000000  0.000000  0.053069      ...        0.000000  0.040858
# 4     0.000000  0.000000  0.062000      ...        0.000000  0.047733
# 5     0.000000  0.000000  0.000000      ...        0.000000  0.000000
# 6     0.051445  0.000000  0.000000      ...        0.000000  0.065333
# 7     0.060355  0.000000  0.000000      ...        0.000000  0.000000
# 8     0.000000  0.000000  0.000000      ...        0.000000  0.050519
# 9     0.000000  0.000000  0.000000      ...        0.000000  0.061820
# 10    0.000000  0.000000  0.000000      ...        0.084896  0.000000
# 11    0.025715  0.000000  0.033520      ...        0.000000  0.000000
# 12    0.048389  0.000000  0.000000      ...        0.000000  0.061168
# 13    0.000000  0.000000  0.000000      ...        0.000000  0.000000
# 14    0.043462  0.000000  0.000000      ...        0.039074  0.000000
# 15    0.000000  0.000000  0.000000      ...        0.023574  0.000000
# 16    0.000000  0.000000  0.000000      ...        0.000000  0.000000
# 17    0.000000  0.000000  0.000000      ...        0.041962  0.000000
# 18    0.000000  0.061476  0.000000      ...        0.027153  0.061264
# 19    0.000000  0.000000  0.000000      ...        0.032540  0.000000
# 20    0.000000  0.000000  0.000000      ...        0.000000  0.000000
# 21    0.000000  0.000000  0.000000      ...        0.000000  0.000000
# 22    0.000000  0.000000  0.000000      ...        0.000000  0.000000
# 23    0.054313  0.064967  0.000000      ...        0.000000  0.000000
# 24    0.000000  0.041284  0.000000      ...        0.023327  0.000000
# 25    0.000000  0.000000  0.000000      ...        0.100000  0.000000
# 26    0.000000  0.000000  0.054459      ...        0.043477  0.000000
# 27    0.094880  0.061405  0.000000      ...        0.000000  0.000000
# 28    0.049363  0.000000  0.000000      ...        0.000000  0.000000
# 29    0.000000  0.000000  0.000000      ...        0.000000  0.000000
# ...        ...       ...       ...      ...             ...       ...
# 1324  0.000000  0.066060  0.000000      ...        0.035584  0.000000
# 1325  0.000000  0.000000  0.000000      ...        0.028169  0.000000
# 1326  0.000000  0.000000  0.000000      ...        0.000000  0.000000
# 1327  0.025882  0.000000  0.000000      ...        0.000000  0.000000
# 1328  0.051970  0.033431  0.000000      ...        0.028378  0.000000
# 1329  0.098119  0.000000  0.000000      ...        0.041503  0.000000
# 1330  0.000000  0.041967  0.000000      ...        0.000000  0.000000
# 1331  0.000000  0.000000  0.000000      ...        0.029681  0.000000
# 1332  0.061861  0.000000  0.000000      ...        0.000000  0.000000
# 1333  0.042243  0.000000  0.000000      ...        0.023078  0.000000
# 1334  0.036883  0.000000  0.000000      ...        0.032594  0.000000
# 1335  0.000000  0.000000  0.000000      ...        0.000000  0.000000
# 1336  0.000000  0.000000  0.000000      ...        0.081063  0.000000
# 1337  0.061379  0.000000  0.000000      ...        0.000000  0.028142
# 1338  0.061063  0.000000  0.000000      ...        0.000000  0.000000
# 1339  0.000000  0.031931  0.000000      ...        0.000000  0.051657
# 1340  0.000000  0.000000  0.000000      ...        0.000000  0.051082
# 1341  0.000000  0.000000  0.000000      ...        0.000000  0.000000
# 1342  0.000000  0.000000  0.000000      ...        0.029302  0.047035
# 1343  0.000000  0.000000  0.000000      ...        0.033679  0.032628
# 1344  0.000000  0.000000  0.000000      ...        0.000000  0.000000
# 1345  0.000000  0.000000  0.000000      ...        0.032415  0.100000
# 1346  0.086447  0.000000  0.000000      ...        0.084753  0.000000
# 1347  0.000000  0.000000  0.000000      ...        0.041828  0.000000
# 1348  0.000000  0.000000  0.000000      ...        0.000000  0.034432
# 1349  0.000000  0.000000  0.000000      ...        0.033128  0.000000
# 1350  0.000000  0.000000  0.000000      ...        0.020370  0.076870
# 1351  0.133906  0.000000  0.000000      ...        0.040527  0.000000
# 1352  0.000000  0.000000  0.000000      ...        0.000000  0.000000
# 1353  0.000000  0.000000  0.000000      ...        0.041726  0.000000
#
#           york     Open     High      Low    Settle    Volume  \
# 0     0.000000  12777.0  12855.0  12684.0  12717.00  138310.0
# 1     0.000000  12731.0  12803.0  12509.0  12544.00  167420.0
# 2     0.000000  12545.0  12581.0  12464.0  12522.00  152927.0
# 3     0.000000  12520.0  12573.0  12434.0  12570.00  167779.0
# 4     0.000000  12579.0  12764.0  12573.0  12738.00  126099.0
# 5     0.000000  12733.0  12777.0  12666.0  12759.00  122895.0
# 6     0.000000  12757.0  12813.0  12696.0  12800.00   82562.0
# 7     0.000000  12802.0  12982.0  12801.0  12961.00   61917.0
# 8     0.000000  12949.0  12951.0  12870.0  12936.00   90154.0
# 9     0.000000  12940.0  12971.0  12845.0  12862.00  125648.0
# 10    0.000000  12867.0  12967.0  12740.0  12957.00  171456.0
# 11    0.064251  12961.0  13049.0  12939.0  13021.00  136755.0
# 12    0.000000  12987.0  13056.0  12973.0  13008.00  112994.0
# 13    0.000000  13003.0  13080.0  12930.0  12950.00  121995.0
# 14    0.000000  12940.0  13008.0  12914.0  12933.00  116192.0
# 15    0.000000  12919.0  13076.0  12905.0  13024.00  173092.0
# 16    0.000000  13015.0  13073.0  12997.0  13063.00  106044.0
# 17    0.000000  13070.0  13154.0  13037.0  13143.00  141385.0
# 18    0.000000  13147.0  13194.0  13103.0  13187.00   89273.0
# 19    0.000000  13169.0  13304.0  13152.0  13278.00  115980.0
# 20    0.000000  13275.0  13326.0  13221.0  13230.00  141546.0
# 21    0.000000  13221.0  13269.0  13145.0  13157.00  136657.0
# 22    0.104226  13157.0  13216.0  13116.0  13150.00   50307.0
# 23    0.060473  13188.0  13255.0  13140.0  13245.00   39599.0
# 24    0.042980  13246.0  13362.0  13226.0  13329.00   33897.0
# 25    0.000000  13331.0  13374.0  13229.0  13268.00   34263.0
# 26    0.000000  13227.0  13324.0  13218.0  13322.00   15834.0
# 27    0.000000  13312.0  13313.0  13021.0  13249.52    2121.0
# 28    0.000000  13133.0  13136.0  13060.0  13065.00   22366.0
# 29    0.000000  13094.0  13111.0  13011.0  13048.00   37860.0
# ...        ...      ...      ...      ...       ...       ...
# 1324  0.000000  24951.0  25257.0  24724.0  24782.00  254310.0
# 1325  0.000000  24783.0  25137.0  24576.0  25013.00  276284.0
# 1326  0.000000  25019.0  25325.0  24996.0  25314.00  203948.0
# 1327  0.000000  25328.0  25774.0  25300.0  25758.00  189537.0
# 1328  0.000000  25758.0  25813.0  25388.0  25429.00  308510.0
# 1329  0.000000  25411.0  25577.0  25018.0  25038.00  270530.0
# 1330  0.000000  25090.0  25185.0  24431.0  24620.00  450881.0
# 1331  0.000000  24616.0  24670.0  24204.0  24535.00  397142.0
# 1332  0.000000  24483.0  24955.0  24311.0  24864.00  309660.0
# 1333  0.000000  24885.0  25047.0  24695.0  24852.00  262663.0
# 1334  0.000000  24659.0  24845.0  24410.0  24795.00  313894.0
# 1335  0.000000  24784.0  24956.0  24704.0  24892.00  228978.0
# 1336  0.060830  24879.0  25346.0  24841.0  25335.00  153047.0
# 1337  0.080062  25335.0  25510.0  25151.0  25208.00  116773.0
# 1338  0.000000  25196.0  25378.0  24945.0  25027.00  102167.0
# 1339  0.000000  24985.0  25153.0  24670.0  24770.00   83440.0
# 1340  0.000000  24784.0  25059.0  24675.0  24907.00   60747.0
# 1341  0.000000  24921.0  24948.0  24823.0  24879.17    2557.0
# 1342  0.000000  24976.0  24984.0  24461.0  24691.00  272836.0
# 1343  0.000000  24671.0  24813.0  24608.0  24765.00  190952.0
# 1344  0.000000  24769.0  24998.0  24660.0  24727.00  225022.0
# 1345  0.000000  24732.0  24803.0  23932.0  23963.00  408367.0
# 1346  0.045132  23999.0  24103.0  23496.0  23612.00  482624.0
# 1347  0.000000  23609.0  24223.0  23551.0  24191.00  321534.0
# 1348  0.051924  24201.0  24435.0  23691.0  23859.00  380005.0
# 1349  0.000000  23854.0  24075.0  23707.0  23860.00  490323.0
# 1350  0.000000  23889.0  24288.0  23797.0  24147.00  297290.0
# 1351  0.000000  24097.0  24147.0  23306.0  23552.00  355871.0
# 1352  0.000000  23609.0  24010.0  23545.0  23984.00  354073.0
# 1353  0.000000  23981.0  24282.0  23361.0  24265.00  381535.0
#
#       Previous Day Open Interest  Next Day Last
# 0                       101101.0       12544.00
# 1                       101005.0       12522.00
# 2                       101319.0       12570.00
# 3                       100484.0       12738.00
# 4                        94345.0       12759.00
# 5                        95051.0       12800.00
# 6                        95921.0       12961.00
# 7                        96069.0       12936.00
# 8                        94842.0       12862.00
# 9                        95474.0       12957.00
# 10                       95845.0       13021.00
# 11                       92127.0       13008.00
# 12                       93114.0       12950.00
# 13                       89500.0       12933.00
# 14                       91217.0       13024.00
# 15                       93873.0       13063.00
# 16                       94626.0       13143.00
# 17                       91375.0       13187.00
# 18                       92332.0       13278.00
# 19                       91799.0       13230.00
# 20                       93532.0       13157.00
# 21                       92483.0       13150.00
# 22                       80256.0       13245.00
# 23                       68203.0       13329.00
# 24                       54628.0       13268.00
# 25                       48005.0       13322.00
# 26                       46878.0       13249.52
# 27                       47600.0       13065.00
# 28                       96228.0       13048.00
# 29                       96020.0       13003.00
# ...                          ...            ...
# 1324                    116491.0       25031.00
# 1325                    115895.0       25300.00
# 1326                    116277.0       25759.00
# 1327                    115278.0       25427.00
# 1328                    113457.0       25090.00
# 1329                    116354.0       24638.00
# 1330                    111656.0       24539.00
# 1331                    112246.0       24881.00
# 1332                    115615.0       24851.00
# 1333                    111013.0       24790.00
# 1334                    111841.0       24886.00
# 1335                    110747.0       25340.00
# 1336                    106230.0       25206.00
# 1337                     90071.0       25010.00
# 1338                     77318.0       24784.00
# 1339                     57743.0       24938.00
# 1340                     49985.0       24881.00
# 1341                     41425.0       24675.00
# 1342                    106972.0       24774.00
# 1343                    106977.0       24728.00
# 1344                    106080.0       24001.00
# 1345                    106660.0       23586.00
# 1346                    107565.0       24202.00
# 1347                    106316.0       23847.00
# 1348                    102806.0       23870.00
# 1349                    103075.0       24096.00
# 1350                    103579.0       23620.00
# 1351                     98611.0       23981.00
# 1352                    101366.0       24243.00
# 1353                     96215.0       24480.00
#
# [1354 rows x 214 columns]

# %%
import numpy as np
import tensorflow as tf

#define constant variable, hidden layer units and learn rate
rnnUnit = 10     
inputSize = 212     
outputSize = 1
learningRate = 0.0006    

#training data
data = dataset.iloc[:,1:214].values
#print(data)

# %%
#get training dataset
def getTrainingData( batchSize, timeStep, trainBegin, trainEnd, data):
    batch_index = []
    data_train = data[trainBegin:trainEnd]
    mean = np.mean(data_train, axis=0)
    std = np.std(data_train, axis=0)
    
    # Stardardization
    normalized_train_data = (data_train-mean)/std  
    train_x,train_y = [],[]   
    for i in range(len(normalized_train_data)-timeStep):
       if i % batchSize == 0:
           batch_index.append(i)
       x=normalized_train_data[i:i+timeStep, :inputSize]
       y=normalized_train_data[i:i+timeStep, inputSize, np.newaxis]
       train_x.append(x.tolist())
       train_y.append(y.tolist())
    batch_index.append((len(normalized_train_data)-timeStep))
    return batch_index, train_x, train_y

# %%
#get test dataset
def getTestData( timeStep, testBegin, trainEnd, data):
    data_test = data[testBegin:trainEnd]
    mean = np.mean(data_test, axis=0)
    std = np.std(data_test,axis=0)
    
    # Stardardization
    normalized_test_data=(data_test-mean)/std  
    size=(len(normalized_test_data)+timeStep-1)//timeStep  #有size个sample
        
    test_x,test_y=[],[]
    for i in range(size-1): 
       x=normalized_test_data[i*timeStep:(i+1)*timeStep, :inputSize]
       y=normalized_test_data[i*timeStep:(i+1)*timeStep, inputSize]
       test_x.append(x.tolist())
       test_y.extend(y)
    
        
    test_x.append((normalized_test_data[(i+1)*timeStep:, :inputSize]).tolist())
    test_y.extend((normalized_test_data[(i+1)*timeStep:, inputSize]).tolist())
     
    return mean, std, test_x, test_y

# %%
weights={
        'in':tf.Variable(tf.random_normal([inputSize,rnnUnit])),
        'out':tf.Variable(tf.random_normal([rnnUnit,1]))
}
biases={
        'in':tf.Variable(tf.constant(0.1,shape=[rnnUnit,])),
        'out':tf.Variable(tf.constant(0.1,shape=[1,]))
}

#LSTM cell
def lstm(X):   
    
    #define neural networks parameters
    #define input/ouput weight, bias
   
    batchSize = tf.shape(X)[0]
    timeStep = tf.shape(X)[1]
    w_in = weights['in']
    b_in = biases['in']
    input = tf.reshape(X,[-1, inputSize])  
    input_rnn = tf.matmul(input,w_in)+b_in
    input_rnn = tf.reshape(input_rnn,[-1, timeStep, rnnUnit])  
    cell = tf.contrib.rnn.core_rnn_cell.BasicLSTMCell(rnnUnit, reuse = tf.get_variable_scope().reuse )
    init_state = cell.zero_state(batchSize, dtype=tf.float32)
    with tf.variable_scope("rnn", reuse = None):
        output_rnn, final_states=tf.nn.dynamic_rnn(cell, input_rnn, initial_state=init_state, dtype=tf.float32)
    
    output = tf.reshape(output_rnn,[-1,rnnUnit]) 
    w_out = weights['out']
    b_out = biases['out']
    pred = tf.matmul(output,w_out)+b_out
    return pred, final_states

# %%
#train LSTM
def trainLSTM( batchSize, timeStep, trainBegin, trainEnd, data):
    
    X = tf.placeholder(tf.float32, shape=[None, timeStep, inputSize])
    Y = tf.placeholder(tf.float32, shape=[None, timeStep, outputSize])
    batch_index, train_x, train_y = getTrainingData( batchSize, timeStep, trainBegin, trainEnd, data)
    
    with tf.variable_scope("lstm_tfidf_14_1y"):
        pred, _ = lstm(X)
        
    loss = tf.reduce_mean(tf.square(tf.reshape(pred,[-1])-tf.reshape(Y, [-1])))
    train_op = tf.train.AdamOptimizer(learningRate).minimize(loss)
    saver = tf.train.Saver(tf.global_variables(), max_to_keep=15)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        #number of iteration
        for i in range(1000):     
            for step in range(len(batch_index)-1):
                _, loss_ = sess.run([train_op, loss], feed_dict={ X: train_x[batch_index[step]:batch_index[step+1]], Y: train_y[batch_index[step]:batch_index[step+1]]})
            print("Number of iterations:", i," loss:", loss_)
        print("Model saves: ", saver.save(sess, './model_tfidf.ckpt'))
        print("The training is finished")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Model prediction
def prediction(timeStep, testBegin, trainEnd, data):
    X = tf.placeholder(tf.float32, shape=[None, timeStep, inputSize])
    mean, std, test_x, test_y = getTestData(timeStep, testBegin, trainEnd, data)
    
    #print(len(test_x))
    #print(test_x)
    #print(len(test_y))    
    
    with tf.variable_scope("lstm_tfidf_14_1y", reuse=True):
        pred, _ = lstm(X)
           
    saver = tf.train.Saver(tf.global_variables())
    with tf.Session() as sess: 
        #read parameters
        module_file = tf.train.latest_checkpoint('./')
        saver.restore(sess, module_file)
        test_predict = []
        
        for step in range(len(test_x)-1):
          prob = sess.run( pred, feed_dict={X:[test_x[step]]} )
          #pprint([test_x[step]]) 
          predict=prob.reshape((-1))
          #pprint(predict)
          test_predict.extend(predict)
        
        test_y = np.array(test_y)*std[inputSize]+mean[inputSize]
        test_predict = np.array(test_predict)*std[inputSize]+mean[inputSize]
        
        

        PMSE = np.average(np.abs(test_predict[20:]-test_y[20:len(test_predict)])/test_y[20:len(test_predict)])  
        print("PMSE:", PMSE)
             
        RMSE = np.sqrt(((test_predict[20:]-test_y[20:len(test_predict)]) ** 2).mean())    
        print("RMSE:", RMSE)        
          
        plt.figure()
        xAxis = range(20, len(test_predict));
        plt.plot(xAxis, test_predict[20:], '-bo',)
        plt.plot(xAxis, test_y[20:len(test_predict)], '-ro')      
        plt.show()
        
    return test_predict

# %%
# run trainLSTM
trainLSTM( batchSize=32, timeStep=20, trainBegin=1000, trainEnd=1300, data=data)
# run prediction
prediction( timeStep=20, testBegin=1300, trainEnd=1400, data=data)
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Number of iterations: 0  loss: 4.361647
# Number of iterations: 1  loss: 4.1815615
# Number of iterations: 2  loss: 3.998505
# Number of iterations: 3  loss: 3.827314
# Number of iterations: 4  loss: 3.6708863
# Number of iterations: 5  loss: 3.529099
# Number of iterations: 6  loss: 3.399086
# Number of iterations: 7  loss: 3.2765634
# Number of iterations: 8  loss: 3.1558568
# Number of iterations: 9  loss: 3.041513
# Number of iterations: 10  loss: 2.9455943
# Number of iterations: 11  loss: 2.8590431
# Number of iterations: 12  loss: 2.7736044
# Number of iterations: 13  loss: 2.689358
# Number of iterations: 14  loss: 2.6137438
# Number of iterations: 15  loss: 2.5453901
# Number of iterations: 16  loss: 2.4800653
# Number of iterations: 17  loss: 2.4171035
# Number of iterations: 18  loss: 2.3572016
# Number of iterations: 19  loss: 2.300804
# Number of iterations: 20  loss: 2.2479055
# Number of iterations: 21  loss: 2.1981637
# Number of iterations: 22  loss: 2.1510813
# Number of iterations: 23  loss: 2.1061587
# Number of iterations: 24  loss: 2.062894
# Number of iterations: 25  loss: 2.020637
# Number of iterations: 26  loss: 1.9783663
# Number of iterations: 27  loss: 1.9342468
# Number of iterations: 28  loss: 1.8851854
# Number of iterations: 29  loss: 1.8337344
# Number of iterations: 30  loss: 1.7891103
# Number of iterations: 31  loss: 1.742792
# Number of iterations: 32  loss: 1.6946101
# Number of iterations: 33  loss: 1.6591061
# Number of iterations: 34  loss: 1.627341
# Number of iterations: 35  loss: 1.5968927
# Number of iterations: 36  loss: 1.5674789
# Number of iterations: 37  loss: 1.5389391
# Number of iterations: 38  loss: 1.5110148
# Number of iterations: 39  loss: 1.4833566
# Number of iterations: 40  loss: 1.4555358
# Number of iterations: 41  loss: 1.4270165
# Number of iterations: 42  loss: 1.3970948
# Number of iterations: 43  loss: 1.364861
# Number of iterations: 44  loss: 1.3294517
# Number of iterations: 45  loss: 1.2910994
# Number of iterations: 46  loss: 1.2516265
# Number of iterations: 47  loss: 1.2119329
# Number of iterations: 48  loss: 1.1717267
# Number of iterations: 49  loss: 1.1315131
# Number of iterations: 50  loss: 1.0925255
# Number of iterations: 51  loss: 1.055839
# Number of iterations: 52  loss: 1.0218396
# Number of iterations: 53  loss: 0.99032265
# Number of iterations: 54  loss: 0.960882
# Number of iterations: 55  loss: 0.93320847
# Number of iterations: 56  loss: 0.9071769
# Number of iterations: 57  loss: 0.88278115
# Number of iterations: 58  loss: 0.86002123
# Number of iterations: 59  loss: 0.83883
# Number of iterations: 60  loss: 0.81906205
# Number of iterations: 61  loss: 0.80052173
# Number of iterations: 62  loss: 0.78299886
# Number of iterations: 63  loss: 0.7662984
# Number of iterations: 64  loss: 0.7502518
# Number of iterations: 65  loss: 0.73472047
# Number of iterations: 66  loss: 0.7195883
# Number of iterations: 67  loss: 0.7047471
# Number of iterations: 68  loss: 0.6900939
# Number of iterations: 69  loss: 0.6755599
# Number of iterations: 70  loss: 0.66113406
# Number of iterations: 71  loss: 0.6468504
# Number of iterations: 72  loss: 0.6327625
# Number of iterations: 73  loss: 0.61892396
# Number of iterations: 74  loss: 0.6053771
# Number of iterations: 75  loss: 0.5921459
# Number of iterations: 76  loss: 0.57923436
# Number of iterations: 77  loss: 0.5666275
# Number of iterations: 78  loss: 0.55429953
# Number of iterations: 79  loss: 0.5422185
# Number of iterations: 80  loss: 0.5303524
# Number of iterations: 81  loss: 0.5186708
# Number of iterations: 82  loss: 0.50714797
# Number of iterations: 83  loss: 0.49576434
# Number of iterations: 84  loss: 0.48450935
# Number of iterations: 85  loss: 0.47338188
# Number of iterations: 86  loss: 0.46239123
# Number of iterations: 87  loss: 0.45155838
# Number of iterations: 88  loss: 0.440913
# Number of iterations: 89  loss: 0.4304891
# Number of iterations: 90  loss: 0.42031977
# Number of iterations: 91  loss: 0.41042995
# Number of iterations: 92  loss: 0.4008304
# Number of iterations: 93  loss: 0.3915157
# Number of iterations: 94  loss: 0.3824643
# Number of iterations: 95  loss: 0.37364748
# Number of iterations: 96  loss: 0.365046
# Number of iterations: 97  loss: 0.35665923
# Number of iterations: 98  loss: 0.34851012
# Number of iterations: 99  loss: 0.34064287
# Number of iterations: 100  loss: 0.33311743
# Number of iterations: 101  loss: 0.32598984
# Number of iterations: 102  loss: 0.31929
# Number of iterations: 103  loss: 0.31300604
# Number of iterations: 104  loss: 0.3070897
# Number of iterations: 105  loss: 0.30153066
# Number of iterations: 106  loss: 0.29630497
# Number of iterations: 107  loss: 0.29133898
# Number of iterations: 108  loss: 0.28657857
# Number of iterations: 109  loss: 0.28197846
# Number of iterations: 110  loss: 0.2774979
# Number of iterations: 111  loss: 0.27311122
# Number of iterations: 112  loss: 0.26881555
# Number of iterations: 113  loss: 0.26461324
# Number of iterations: 114  loss: 0.26049647
# Number of iterations: 115  loss: 0.25645918
# Number of iterations: 116  loss: 0.2525055
# Number of iterations: 117  loss: 0.24864244
# Number of iterations: 118  loss: 0.24487703
# Number of iterations: 119  loss: 0.2412147
# Number of iterations: 120  loss: 0.23765938
# Number of iterations: 121  loss: 0.23421349
# Number of iterations: 122  loss: 0.2308783
# Number of iterations: 123  loss: 0.22765331
# Number of iterations: 124  loss: 0.22453716
# Number of iterations: 125  loss: 0.22152728
# Number of iterations: 126  loss: 0.21862005
# Number of iterations: 127  loss: 0.215811
# Number of iterations: 128  loss: 0.21309525
# Number of iterations: 129  loss: 0.210467
# Number of iterations: 130  loss: 0.20791979
# Number of iterations: 131  loss: 0.20544703
# Number of iterations: 132  loss: 0.20304276
# Number of iterations: 133  loss: 0.20070308
# Number of iterations: 134  loss: 0.19842796
# Number of iterations: 135  loss: 0.19622153
# Number of iterations: 136  loss: 0.19408722
# Number of iterations: 137  loss: 0.19198821
# Number of iterations: 138  loss: 0.18982492
# Number of iterations: 139  loss: 0.18775941
# Number of iterations: 140  loss: 0.1858556
# Number of iterations: 141  loss: 0.18405595
# Number of iterations: 142  loss: 0.18230484
# Number of iterations: 143  loss: 0.18062967
# Number of iterations: 144  loss: 0.17901331
# Number of iterations: 145  loss: 0.17746112
# Number of iterations: 146  loss: 0.17594032
# Number of iterations: 147  loss: 0.17447156
# Number of iterations: 148  loss: 0.17301038
# Number of iterations: 149  loss: 0.17157109
# Number of iterations: 150  loss: 0.17011674
# Number of iterations: 151  loss: 0.16865483
# Number of iterations: 152  loss: 0.16719504
# Number of iterations: 153  loss: 0.16571401
# Number of iterations: 154  loss: 0.1642567
# Number of iterations: 155  loss: 0.16278155
# Number of iterations: 156  loss: 0.16133493
# Number of iterations: 157  loss: 0.15987636
# Number of iterations: 158  loss: 0.15844183
# Number of iterations: 159  loss: 0.15699892
# Number of iterations: 160  loss: 0.15557176
# Number of iterations: 161  loss: 0.1541353
# Number of iterations: 162  loss: 0.15270576
# Number of iterations: 163  loss: 0.15126161
# Number of iterations: 164  loss: 0.14981447
# Number of iterations: 165  loss: 0.14834465
# Number of iterations: 166  loss: 0.14686127
# Number of iterations: 167  loss: 0.14534725
# Number of iterations: 168  loss: 0.14381291
# Number of iterations: 169  loss: 0.14224602
# Number of iterations: 170  loss: 0.14066277
# Number of iterations: 171  loss: 0.13905846
# Number of iterations: 172  loss: 0.13745861
# Number of iterations: 173  loss: 0.13586499
# Number of iterations: 174  loss: 0.13431005
# Number of iterations: 175  loss: 0.13279395
# Number of iterations: 176  loss: 0.13134833
# Number of iterations: 177  loss: 0.129962
# Number of iterations: 178  loss: 0.12866014
# Number of iterations: 179  loss: 0.12741789
# Number of iterations: 180  loss: 0.12625538
# Number of iterations: 181  loss: 0.12513968
# Number of iterations: 182  loss: 0.12408938
# Number of iterations: 183  loss: 0.123069905
# Number of iterations: 184  loss: 0.122100115
# Number of iterations: 185  loss: 0.12114762
# Number of iterations: 186  loss: 0.12023074
# Number of iterations: 187  loss: 0.11932053
# Number of iterations: 188  loss: 0.11843378
# Number of iterations: 189  loss: 0.117544904
# Number of iterations: 190  loss: 0.11666799
# Number of iterations: 191  loss: 0.11578023
# Number of iterations: 192  loss: 0.11489201
# Number of iterations: 193  loss: 0.113981985
# Number of iterations: 194  loss: 0.1130558
# Number of iterations: 195  loss: 0.1120914
# Number of iterations: 196  loss: 0.111087605
# Number of iterations: 197  loss: 0.11001838
# Number of iterations: 198  loss: 0.10887335
# Number of iterations: 199  loss: 0.107622124
# Number of iterations: 200  loss: 0.10625358
# Number of iterations: 201  loss: 0.10475629
# Number of iterations: 202  loss: 0.10316651
# Number of iterations: 203  loss: 0.10154865
# Number of iterations: 204  loss: 0.100002736
# Number of iterations: 205  loss: 0.09859225
# Number of iterations: 206  loss: 0.097346686
# Number of iterations: 207  loss: 0.09624203
# Number of iterations: 208  loss: 0.09525686
# Number of iterations: 209  loss: 0.09435304
# Number of iterations: 210  loss: 0.09351768
# Number of iterations: 211  loss: 0.09272475
# Number of iterations: 212  loss: 0.09197322
# Number of iterations: 213  loss: 0.091245
# Number of iterations: 214  loss: 0.09054499
# Number of iterations: 215  loss: 0.08985878
# Number of iterations: 216  loss: 0.08919389
# Number of iterations: 217  loss: 0.0885379
# Number of iterations: 218  loss: 0.08789911
# Number of iterations: 219  loss: 0.08726656
# Number of iterations: 220  loss: 0.08664856
# Number of iterations: 221  loss: 0.08603522
# Number of iterations: 222  loss: 0.08543472
# Number of iterations: 223  loss: 0.08483812
# Number of iterations: 224  loss: 0.084253274
# Number of iterations: 225  loss: 0.08367185
# Number of iterations: 226  loss: 0.083101496
# Number of iterations: 227  loss: 0.08253436
# Number of iterations: 228  loss: 0.081977926
# Number of iterations: 229  loss: 0.0814247
# Number of iterations: 230  loss: 0.08088207
# Number of iterations: 231  loss: 0.08034273
# Number of iterations: 232  loss: 0.07981419
# Number of iterations: 233  loss: 0.07928922
# Number of iterations: 234  loss: 0.07877528
# Number of iterations: 235  loss: 0.07826528
# Number of iterations: 236  loss: 0.077766515
# Number of iterations: 237  loss: 0.07727201
# Number of iterations: 238  loss: 0.076788746
# Number of iterations: 239  loss: 0.076309904
# Number of iterations: 240  loss: 0.07584203
# Number of iterations: 241  loss: 0.07537859
# Number of iterations: 242  loss: 0.074925676
# Number of iterations: 243  loss: 0.07447696
# Number of iterations: 244  loss: 0.0740382
# Number of iterations: 245  loss: 0.073603466
# Number of iterations: 246  loss: 0.07317795
# Number of iterations: 247  loss: 0.07275615
# Number of iterations: 248  loss: 0.07234292
# Number of iterations: 249  loss: 0.071933016
# Number of iterations: 250  loss: 0.07153106
# Number of iterations: 251  loss: 0.07113197
# Number of iterations: 252  loss: 0.070740364
# Number of iterations: 253  loss: 0.0703512
# Number of iterations: 254  loss: 0.06996896
# Number of iterations: 255  loss: 0.06958869
# Number of iterations: 256  loss: 0.06921494
# Number of iterations: 257  loss: 0.06884272
# Number of iterations: 258  loss: 0.06847666
# Number of iterations: 259  loss: 0.06811155
# Number of iterations: 260  loss: 0.067752324
# Number of iterations: 261  loss: 0.067393556
# Number of iterations: 262  loss: 0.06704033
# Number of iterations: 263  loss: 0.06668706
# Number of iterations: 264  loss: 0.06633908
# Number of iterations: 265  loss: 0.065990426
# Number of iterations: 266  loss: 0.06564687
# Number of iterations: 267  loss: 0.06530194
# Number of iterations: 268  loss: 0.06496197
# Number of iterations: 269  loss: 0.0646198
# Number of iterations: 270  loss: 0.06428253
# Number of iterations: 271  loss: 0.06394213
# Number of iterations: 272  loss: 0.06360654
# Number of iterations: 273  loss: 0.06326669
# Number of iterations: 274  loss: 0.06293178
# Number of iterations: 275  loss: 0.0625912
# Number of iterations: 276  loss: 0.06225575
# Number of iterations: 277  loss: 0.061913047
# Number of iterations: 278  loss: 0.061575867
# Number of iterations: 279  loss: 0.06122958
# Number of iterations: 280  loss: 0.060889363
# Number of iterations: 281  loss: 0.060537983
# Number of iterations: 282  loss: 0.06019365
# Number of iterations: 283  loss: 0.05983599
# Number of iterations: 284  loss: 0.05948668
# Number of iterations: 285  loss: 0.059122153
# Number of iterations: 286  loss: 0.05876766
# Number of iterations: 287  loss: 0.058396436
# Number of iterations: 288  loss: 0.05803733
# Number of iterations: 289  loss: 0.057660643
# Number of iterations: 290  loss: 0.057298176
# Number of iterations: 291  loss: 0.056918047
# Number of iterations: 292  loss: 0.056554142
# Number of iterations: 293  loss: 0.05617286
# Number of iterations: 294  loss: 0.055809323
# Number of iterations: 295  loss: 0.055429015
# Number of iterations: 296  loss: 0.05506718
# Number of iterations: 297  loss: 0.054689184
# Number of iterations: 298  loss: 0.054329734
# Number of iterations: 299  loss: 0.053954612
# Number of iterations: 300  loss: 0.05359776
# Number of iterations: 301  loss: 0.05322551
# Number of iterations: 302  loss: 0.052871123
# Number of iterations: 303  loss: 0.052501492
# Number of iterations: 304  loss: 0.052149557
# Number of iterations: 305  loss: 0.05178229
# Number of iterations: 306  loss: 0.051433075
# Number of iterations: 307  loss: 0.05106841
# Number of iterations: 308  loss: 0.050722647
# Number of iterations: 309  loss: 0.050361194
# Number of iterations: 310  loss: 0.050020143
# Number of iterations: 311  loss: 0.049662955
# Number of iterations: 312  loss: 0.049327962
# Number of iterations: 313  loss: 0.048975985
# Number of iterations: 314  loss: 0.04864834
# Number of iterations: 315  loss: 0.048302468
# Number of iterations: 316  loss: 0.04798352
# Number of iterations: 317  loss: 0.047646634
# Number of iterations: 318  loss: 0.047341958
# Number of iterations: 319  loss: 0.04702917
# Number of iterations: 320  loss: 0.046764087
# Number of iterations: 321  loss: 0.04652109
# Number of iterations: 322  loss: 0.0463655
# Number of iterations: 323  loss: 0.046196382
# Number of iterations: 324  loss: 0.046143416
# Number of iterations: 325  loss: 0.045784164
# Number of iterations: 326  loss: 0.04560593
# Number of iterations: 327  loss: 0.045139078
# Number of iterations: 328  loss: 0.044849563
# Number of iterations: 329  loss: 0.044502012
# Number of iterations: 330  loss: 0.04423033
# Number of iterations: 331  loss: 0.043943636
# Number of iterations: 332  loss: 0.04368925
# Number of iterations: 333  loss: 0.043432258
# Number of iterations: 334  loss: 0.04320162
# Number of iterations: 335  loss: 0.042985167
# Number of iterations: 336  loss: 0.04282348
# Number of iterations: 337  loss: 0.042685922
# Number of iterations: 338  loss: 0.04253064
# Number of iterations: 339  loss: 0.04239191
# Number of iterations: 340  loss: 0.042187206
# Number of iterations: 341  loss: 0.04199108
# Number of iterations: 342  loss: 0.04178363
# Number of iterations: 343  loss: 0.041595973
# Number of iterations: 344  loss: 0.041392483
# Number of iterations: 345  loss: 0.04120373
# Number of iterations: 346  loss: 0.040996823
# Number of iterations: 347  loss: 0.04080591
# Number of iterations: 348  loss: 0.04061306
# Number of iterations: 349  loss: 0.040428706
# Number of iterations: 350  loss: 0.04025093
# Number of iterations: 351  loss: 0.04007805
# Number of iterations: 352  loss: 0.03990931
# Number of iterations: 353  loss: 0.039744936
# Number of iterations: 354  loss: 0.039581653
# Number of iterations: 355  loss: 0.039423328
# Number of iterations: 356  loss: 0.03926399
# Number of iterations: 357  loss: 0.039109822
# Number of iterations: 358  loss: 0.0389536
# Number of iterations: 359  loss: 0.03880197
# Number of iterations: 360  loss: 0.038648807
# Number of iterations: 361  loss: 0.03849939
# Number of iterations: 362  loss: 0.038350906
# Number of iterations: 363  loss: 0.03820556
# Number of iterations: 364  loss: 0.038063366
# Number of iterations: 365  loss: 0.03792306
# Number of iterations: 366  loss: 0.037786372
# Number of iterations: 367  loss: 0.03765033
# Number of iterations: 368  loss: 0.03751754
# Number of iterations: 369  loss: 0.037384927
# Number of iterations: 370  loss: 0.037254907
# Number of iterations: 371  loss: 0.037125025
# Number of iterations: 372  loss: 0.036996976
# Number of iterations: 373  loss: 0.036869213
# Number of iterations: 374  loss: 0.036742464
# Number of iterations: 375  loss: 0.036616158
# Number of iterations: 376  loss: 0.036490146
# Number of iterations: 377  loss: 0.036364507
# Number of iterations: 378  loss: 0.03623881
# Number of iterations: 379  loss: 0.03611336
# Number of iterations: 380  loss: 0.035987996
# Number of iterations: 381  loss: 0.03586248
# Number of iterations: 382  loss: 0.03573799
# Number of iterations: 383  loss: 0.035612766
# Number of iterations: 384  loss: 0.03548999
# Number of iterations: 385  loss: 0.035365734
# Number of iterations: 386  loss: 0.035245467
# Number of iterations: 387  loss: 0.03512285
# Number of iterations: 388  loss: 0.03500551
# Number of iterations: 389  loss: 0.03488493
# Number of iterations: 390  loss: 0.034770593
# Number of iterations: 391  loss: 0.03465206
# Number of iterations: 392  loss: 0.034540337
# Number of iterations: 393  loss: 0.03442352
# Number of iterations: 394  loss: 0.034313917
# Number of iterations: 395  loss: 0.034198582
# Number of iterations: 396  loss: 0.034090623
# Number of iterations: 397  loss: 0.03397624
# Number of iterations: 398  loss: 0.033869293
# Number of iterations: 399  loss: 0.03375523
# Number of iterations: 400  loss: 0.033648696
# Number of iterations: 401  loss: 0.03353442
# Number of iterations: 402  loss: 0.033427954
# Number of iterations: 403  loss: 0.033313118
# Number of iterations: 404  loss: 0.033206798
# Number of iterations: 405  loss: 0.03309131
# Number of iterations: 406  loss: 0.032985486
# Number of iterations: 407  loss: 0.03286951
# Number of iterations: 408  loss: 0.03276476
# Number of iterations: 409  loss: 0.032648508
# Number of iterations: 410  loss: 0.032545604
# Number of iterations: 411  loss: 0.032429248
# Number of iterations: 412  loss: 0.032329172
# Number of iterations: 413  loss: 0.032212753
# Number of iterations: 414  loss: 0.03211664
# Number of iterations: 415  loss: 0.03200013
# Number of iterations: 416  loss: 0.03190935
# Number of iterations: 417  loss: 0.031792525
# Number of iterations: 418  loss: 0.031706735
# Number of iterations: 419  loss: 0.031588677
# Number of iterations: 420  loss: 0.0315028
# Number of iterations: 421  loss: 0.031382248
# Number of iterations: 422  loss: 0.031291645
# Number of iterations: 423  loss: 0.031170988
# Number of iterations: 424  loss: 0.031078395
# Number of iterations: 425  loss: 0.030961525
# Number of iterations: 426  loss: 0.030870073
# Number of iterations: 427  loss: 0.030757213
# Number of iterations: 428  loss: 0.030667422
# Number of iterations: 429  loss: 0.03055706
# Number of iterations: 430  loss: 0.030468594
# Number of iterations: 431  loss: 0.030359238
# Number of iterations: 432  loss: 0.030272042
# Number of iterations: 433  loss: 0.030163424
# Number of iterations: 434  loss: 0.030077316
# Number of iterations: 435  loss: 0.029969947
# Number of iterations: 436  loss: 0.029883342
# Number of iterations: 437  loss: 0.029778274
# Number of iterations: 438  loss: 0.029687531
# Number of iterations: 439  loss: 0.029586766
# Number of iterations: 440  loss: 0.029489996
# Number of iterations: 441  loss: 0.029394865
# Number of iterations: 442  loss: 0.029302472
# Number of iterations: 443  loss: 0.029206824
# Number of iterations: 444  loss: 0.029120743
# Number of iterations: 445  loss: 0.029015502
# Number of iterations: 446  loss: 0.028925031
# Number of iterations: 447  loss: 0.028803451
# Number of iterations: 448  loss: 0.028706882
# Number of iterations: 449  loss: 0.028582543
# Number of iterations: 450  loss: 0.028512696
# Number of iterations: 451  loss: 0.02846717
# Number of iterations: 452  loss: 0.028587123
# Number of iterations: 453  loss: 0.028774785
# Number of iterations: 454  loss: 0.029033847
# Number of iterations: 455  loss: 0.028915081
# Number of iterations: 456  loss: 0.0286741
# Number of iterations: 457  loss: 0.028330082
# Number of iterations: 458  loss: 0.028084109
# Number of iterations: 459  loss: 0.027902007
# Number of iterations: 460  loss: 0.027772928
# Number of iterations: 461  loss: 0.027659947
# Number of iterations: 462  loss: 0.027560124
# Number of iterations: 463  loss: 0.027465208
# Number of iterations: 464  loss: 0.02737235
# Number of iterations: 465  loss: 0.027287582
# Number of iterations: 466  loss: 0.027200878
# Number of iterations: 467  loss: 0.027123086
# Number of iterations: 468  loss: 0.027040565
# Number of iterations: 469  loss: 0.026967326
# Number of iterations: 470  loss: 0.026886303
# Number of iterations: 471  loss: 0.026820067
# Number of iterations: 472  loss: 0.02674253
# Number of iterations: 473  loss: 0.026687587
# Number of iterations: 474  loss: 0.026617168
# Number of iterations: 475  loss: 0.026571201
# Number of iterations: 476  loss: 0.026505152
# Number of iterations: 477  loss: 0.026457192
# Number of iterations: 478  loss: 0.02638292
# Number of iterations: 479  loss: 0.026322756
# Number of iterations: 480  loss: 0.02623136
# Number of iterations: 481  loss: 0.026160281
# Number of iterations: 482  loss: 0.026060743
# Number of iterations: 483  loss: 0.025988996
# Number of iterations: 484  loss: 0.025892133
# Number of iterations: 485  loss: 0.025823982
# Number of iterations: 486  loss: 0.0257329
# Number of iterations: 487  loss: 0.02566762
# Number of iterations: 488  loss: 0.025581343
# Number of iterations: 489  loss: 0.025517562
# Number of iterations: 490  loss: 0.025435308
# Number of iterations: 491  loss: 0.025373084
# Number of iterations: 492  loss: 0.025295353
# Number of iterations: 493  loss: 0.025235621
# Number of iterations: 494  loss: 0.025163552
# Number of iterations: 495  loss: 0.025105942
# Number of iterations: 496  loss: 0.025038987
# Number of iterations: 497  loss: 0.024980443
# Number of iterations: 498  loss: 0.024915537
# Number of iterations: 499  loss: 0.024850849
# Number of iterations: 500  loss: 0.024783002
# Number of iterations: 501  loss: 0.024707261
# Number of iterations: 502  loss: 0.024632286
# Number of iterations: 503  loss: 0.02454432
# Number of iterations: 504  loss: 0.024461597
# Number of iterations: 505  loss: 0.024366463
# Number of iterations: 506  loss: 0.024279136
# Number of iterations: 507  loss: 0.024185304
# Number of iterations: 508  loss: 0.02409742
# Number of iterations: 509  loss: 0.024009552
# Number of iterations: 510  loss: 0.023922296
